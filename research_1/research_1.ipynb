# %%
import pandas as pd
excel = pd.read_excel("bankloan.xlsx")
excel
excel.to_excel(r'out_excel.xlsx')

# %%
csv = pd.read_csv("bankloan.csv")
csv
csv.to_csv(r'out_csv.csv')

# %%
text = pd.read_table("bankloan1.txt", encoding='gbk', engine='python')
text
text.to_csv(r'out_text.text', encoding='gbk')

# %%
import tushare as ts
print(ts.__version__)
# Out:
# 1.2.89

# %%
ts.set_token('62ba54ab2804c493a21c1171f43e906b827527ec1962619c66b679cc')   #设置token，只需设置一次
api = ts.pro_api()#初始化接口

# %%
df = api.daily(ts_code='603993.SH',start_date='20180101',end_date='20220329')
df
# Out:
#         ts_code trade_date  open  high   low  close  pre_close  change  \
# 0     603993.SH   20220329  5.30  5.39  5.27   5.33       5.33    0.00
# 1     603993.SH   20220328  5.38  5.41  5.24   5.33       5.47   -0.14
# 2     603993.SH   20220325  5.43  5.60  5.40   5.47       5.44    0.03
# 3     603993.SH   20220324  5.31  5.50  5.29   5.44       5.31    0.13
# 4     603993.SH   20220323  5.28  5.33  5.25   5.31       5.24    0.07
# ...         ...        ...   ...   ...   ...    ...        ...     ...
# 1024  603993.SH   20180108  7.11  7.43  7.08   7.30       7.16    0.14
# 1025  603993.SH   20180105  7.17  7.25  7.09   7.16       7.23   -0.07
# 1026  603993.SH   20180104  6.98  7.24  6.97   7.23       7.05    0.18
# 1027  603993.SH   20180103  6.96  7.28  6.94   7.05       6.94    0.11
# 1028  603993.SH   20180102  6.90  6.99  6.82   6.94       6.88    0.06
#
#       pct_chg         vol       amount
# 0      0.0000   757386.12   403348.779
# ...

# %%
df.to_excel(r"603993.xlsx")

# %%
df = api.daily(trade_date='20220328')
df
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     000001.SZ   20220328  14.80  15.05  14.63  14.85      14.98   -0.13
# 1     000002.SZ   20220328  17.10  17.91  17.01  17.77      17.41    0.36
# 2     000004.SZ   20220328  19.75  20.82  19.60  20.39      19.88    0.51
# 3     000005.SZ   20220328   2.19   2.30   2.16   2.27       2.21    0.06
# 4     000006.SZ   20220328   4.60   4.79   4.53   4.76       4.62    0.14
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 4750  871642.BJ   20220328   9.94   9.94   9.50   9.75       9.87   -0.12
# 4751  871857.BJ   20220328  10.38  10.38  10.18  10.23      10.37   -0.14
# 4752  871981.BJ   20220328  29.51  29.51  28.51  28.90      29.51   -0.61
# 4753  872925.BJ   20220328  16.08  16.79  15.81  15.87      16.59   -0.72
# 4754  689009.SH   20220328  44.80  45.50  43.73  45.00      45.23   -0.23
#
#       pct_chg         vol       amount
# 0     -0.8678   727136.99  1078327.302
# ...

# %%
df.to_csv('20220328.csv')

# %%
import tushare as ts

#获取股票1分钟数据
df = ts.pro_bar(ts_code='600000.SH',
                    freq='1min', 
                    start_date='2020-01-07 09:00:00', 
                    end_date='2020-01-08 17:00:00')

print(df)
# Out:
#        ts_code           trade_time   open  close   high    low        vol  \
# 0    600000.SH  2020-01-08 15:00:00  12.32  12.32  12.32  12.32  1485837.0
# 1    600000.SH  2020-01-08 14:59:00  12.32  12.32  12.32  12.32        0.0
# 2    600000.SH  2020-01-08 14:58:00  12.32  12.32  12.32  12.32    22000.0
# 3    600000.SH  2020-01-08 14:57:00  12.32  12.32  12.33  12.32   266196.0
# 4    600000.SH  2020-01-08 14:56:00  12.32  12.32  12.33  12.32   265829.0
# ..         ...                  ...    ...    ...    ...    ...        ...
# 477  600000.SH  2020-01-07 09:34:00  12.55  12.55  12.57  12.55   406300.0
# 478  600000.SH  2020-01-07 09:33:00  12.51  12.55  12.55  12.50   427336.0
# 479  600000.SH  2020-01-07 09:32:00  12.51  12.50  12.52  12.50   350500.0
# 480  600000.SH  2020-01-07 09:31:00  12.51  12.50  12.51  12.50   335700.0
# 481  600000.SH  2020-01-07 09:30:00  12.51  12.51  12.51  12.51   346000.0
#
#          amount trade_date  pre_close
# ...

# %%
df = ts.pro_bar(ts_code='000001.SH',
                    asset='I',
                    freq='1min', 
                    start_date='2020-01-07 09:00:00', 
                    end_date='2020-01-08 17:00:00')    

print(df)
# Out:
# 抱歉，您每分钟最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
# 抱歉，您每分钟最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
# 抱歉，您每分钟最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16632/2297898273.py in <module>
# ----> 1 df = ts.pro_bar(ts_code='000001.SH',
#       2                     asset='I',
#       3                     freq='1min',
#       4                     start_date='2020-01-07 09:00:00',
#       5                     end_date='2020-01-08 17:00:00')
#
# E:\Anaconda\lib\site-packages\tushare\pro\data_pro.py in pro_bar(ts_code, api, start_date, end_date, freq, asset, exchange, adj, ma, factors, adjfactor, offset, limit, contract_type, retry_count)
#     194         else:
#     195             return data
# --> 196     raise IOError('ERROR.')
#     197
# ...

# %%
df = ts.pro_bar(ts_code='150018.SZ',
                    asset='FD',
                    freq='1min', 
                    start_date='2020-01-07 09:00:00', 
                    end_date='2020-01-08 17:00:00')
# Out:
# 抱歉，您每分钟最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
# 抱歉，您每分钟最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
# 抱歉，您每分钟最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16632/146480013.py in <module>
# ----> 1 df = ts.pro_bar(ts_code='150018.SZ',
#       2                     asset='FD',
#       3                     freq='1min',
#       4                     start_date='2020-01-07 09:00:00',
#       5                     end_date='2020-01-08 17:00:00')
#
# E:\Anaconda\lib\site-packages\tushare\pro\data_pro.py in pro_bar(ts_code, api, start_date, end_date, freq, asset, exchange, adj, ma, factors, adjfactor, offset, limit, contract_type, retry_count)
#     194         else:
#     195             return data
# --> 196     raise IOError('ERROR.')
#     197
# ...

# %%
df = pro.coin_mins(symbol='btcusdt',
                    exchange='huobi',
                    freq='1min', 
                    trade_date='20200107')

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16632/2148836521.py in <module>
# ----> 1 df = pro.coin_mins(symbol='btcusdt',
#       2                     exchange='huobi',
#       3                     freq='1min',
#       4                     trade_date='20200107')
#       5
#
# NameError: name 'pro' is not defined

# %%
df_hs300_1 = ts.get_hist_data('hs300',start='2021-01-01',end='2021-12-31')
df_hs300_1
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#                open     high    close      low      volume  price_change  \
# date
# 2021-12-31  4937.46  4950.36  4940.37  4923.14  1213137.38         18.86
# 2021-12-30  4882.16  4940.18  4921.51  4878.65  1216171.75         38.03
# 2021-12-29  4958.65  4958.65  4883.48  4883.48  1135870.00        -72.48
# 2021-12-28  4923.69  4959.14  4955.96  4913.60  1304577.62         36.64
# 2021-12-27  4918.15  4939.69  4919.32  4894.16  1241009.50         -2.02
# ...             ...      ...      ...      ...         ...           ...
# 2021-01-08  5526.29  5547.47  5495.43  5442.69  2043249.50        -18.23
# 2021-01-07  5428.39  5513.66  5513.66  5413.35  2198720.75         95.99
# 2021-01-06  5386.51  5433.47  5417.67  5341.43  1937734.50         49.17
# 2021-01-05  5245.84  5368.50  5368.50  5234.38  2249311.50        100.78
# 2021-01-04  5212.93  5284.43  5267.72  5190.94  2117113.75         56.43
#
# ...

# %%
df_hs300_2 = ts.get_hist_data('hs300',start='2020-01-01',end='2020-12-31')
df_hs300_2
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#                open     high    close      low      volume  price_change  \
# date
# 2020-12-31  5122.48  5215.62  5211.29  5122.48  1716025.12         97.58
# 2020-12-30  5037.98  5113.71  5113.71  5036.63  1486264.50         70.77
# 2020-12-29  5071.45  5077.42  5042.94  5034.31  1411986.62        -21.47
# 2020-12-28  5042.94  5089.34  5064.41  5037.86  1369144.12         22.40
# 2020-12-25  4985.77  5042.10  5042.01  4973.68  1210069.75         41.99
# ...             ...      ...      ...      ...         ...           ...
# 2020-09-11  4572.26  4630.88  4627.28  4563.11  1153024.25         45.30
# 2020-09-10  4632.10  4647.75  4581.98  4572.21  1506528.75         -2.61
# 2020-09-09  4634.25  4645.20  4584.59  4558.03  1622771.12       -109.80
# 2020-09-08  4683.83  4707.90  4694.39  4639.05  1391992.25         25.02
# 2020-09-07  4759.52  4789.30  4669.37  4655.56  1486077.88       -100.85
#
# ...

# %%
df_hs300_1.to_csv(r'hs300.csv')

# %%
excel_tushare = pd.read_excel("603993.xlsx")
excel_tushare
# Out:
#       Unnamed: 0    ts_code  trade_date  open  high   low  close  pre_close  \
# 0              0  603993.SH    20220329  5.30  5.39  5.27   5.33       5.33
# 1              1  603993.SH    20220328  5.38  5.41  5.24   5.33       5.47
# 2              2  603993.SH    20220325  5.43  5.60  5.40   5.47       5.44
# 3              3  603993.SH    20220324  5.31  5.50  5.29   5.44       5.31
# 4              4  603993.SH    20220323  5.28  5.33  5.25   5.31       5.24
# ...          ...        ...         ...   ...   ...   ...    ...        ...
# 1024        1024  603993.SH    20180108  7.11  7.43  7.08   7.30       7.16
# 1025        1025  603993.SH    20180105  7.17  7.25  7.09   7.16       7.23
# 1026        1026  603993.SH    20180104  6.98  7.24  6.97   7.23       7.05
# 1027        1027  603993.SH    20180103  6.96  7.28  6.94   7.05       6.94
# 1028        1028  603993.SH    20180102  6.90  6.99  6.82   6.94       6.88
#
#       change  pct_chg         vol       amount
# ...

# %%
csv_tushare = pd.read_csv('20220328.csv')
csv_tushare
# Out:
#       Unnamed: 0    ts_code  trade_date   open   high    low  close  \
# 0              0  000001.SZ    20220328  14.80  15.05  14.63  14.85
# 1              1  000002.SZ    20220328  17.10  17.91  17.01  17.77
# 2              2  000004.SZ    20220328  19.75  20.82  19.60  20.39
# 3              3  000005.SZ    20220328   2.19   2.30   2.16   2.27
# 4              4  000006.SZ    20220328   4.60   4.79   4.53   4.76
# ...          ...        ...         ...    ...    ...    ...    ...
# 4750        4750  871642.BJ    20220328   9.94   9.94   9.50   9.75
# 4751        4751  871857.BJ    20220328  10.38  10.38  10.18  10.23
# 4752        4752  871981.BJ    20220328  29.51  29.51  28.51  28.90
# 4753        4753  872925.BJ    20220328  16.08  16.79  15.81  15.87
# 4754        4754  689009.SH    20220328  44.80  45.50  43.73  45.00
#
#       pre_close  change  pct_chg         vol       amount
# 0         14.98   -0.13  -0.8678   727136.99  1078327.302
# ...

# %%
csv_tushare_hs300 = pd.read_csv('hs300.csv')
csv_tushare_hs300
# Out:
#            date     open     high    close      low      volume  price_change  \
# 0    2021-12-31  4937.46  4950.36  4940.37  4923.14  1213137.38         18.86
# 1    2021-12-30  4882.16  4940.18  4921.51  4878.65  1216171.75         38.03
# 2    2021-12-29  4958.65  4958.65  4883.48  4883.48  1135870.00        -72.48
# 3    2021-12-28  4923.69  4959.14  4955.96  4913.60  1304577.62         36.64
# 4    2021-12-27  4918.15  4939.69  4919.32  4894.16  1241009.50         -2.02
# ..          ...      ...      ...      ...      ...         ...           ...
# 238  2021-01-08  5526.29  5547.47  5495.43  5442.69  2043249.50        -18.23
# 239  2021-01-07  5428.39  5513.66  5513.66  5413.35  2198720.75         95.99
# 240  2021-01-06  5386.51  5433.47  5417.67  5341.43  1937734.50         49.17
# 241  2021-01-05  5245.84  5368.50  5368.50  5234.38  2249311.50        100.78
# 242  2021-01-04  5212.93  5284.43  5267.72  5190.94  2117113.75         56.43
#
# ...

# %%
from csmarapi.CsmarService import CsmarService    
from csmarapi.ReportUtil import ReportUtil    
csmar = CsmarService()    
csmar.login('2021011561@bistu.edu.cn', 'czh666666')    
data = csmar.query(['Cuntrycd','Stkcd','Stknme','Conme'], "Stkcd like'0%' or Stkcd like'6%' ", 'TRD_Co')    
ReportUtil(data)
# Out:
# +----------+--------+-----------+------------------------------------------------+
# | Cuntrycd | Stkcd  |   Stknme  |                     Conme                      |
# +----------+--------+-----------+------------------------------------------------+
# |    10    | 000001 |  平安银行 |              平安银行股份有限公司              |
# |    10    | 000002 |   万科A   |              万科企业股份有限公司              |
# |    10    | 000003 |  PT 金田A |           金田实业(集团)股份有限公司           |
# |    10    | 000004 |  ST 国华  |          深圳国华网安科技股份有限公司          |
# |    10    | 000005 |  ST 星源  |            深圳世纪星源股份有限公司            |
# |    10    | 000006 |  深振业A  |          深圳市振业(集团)股份有限公司          |
# |    10    | 000007 |   全新好  |            深圳市全新好股份有限公司            |
# |    10    | 000008 |  神州高铁 |            神州高铁技术股份有限公司            |
# |    10    | 000009 |  中国宝安 |            中国宝安集团股份有限公司            |
# |    10    | 000010 |  美丽生态 |            深圳美丽生态股份有限公司            |
# ...
